# %%
## W3A1

# %% [markdown]
# ## W3A1

# %%
n = input()
for  i in n:
# Out:
# 4
# 5
# 6
# 3
# 2
# 1

# %%
n = int(input())
doc_so = [ "so khong" , "so mot" , " so hai", " so ba ", "so bon", "so nam", "so sau" , "so bay", "so tam", "so chin"]
if 0 <= n <= 9 :
    print(doc_so[n])
else:
    print("so ban vua nhap khong hop le")
# Out:
# so bon

# %%
n = int(input())
