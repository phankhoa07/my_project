# %% [markdown]
# # bai 1

# %%
n = list(map(int , input().split()))
final_list = []
for i in range(len(n)) :
    if n[i] not in final_list :
        final_list.append(n[i])
print(final_list)
# Out:
# [5, 55]

# %% [markdown]
# # bai 2

# %%
n = list(map(int, input().split())) 
tong = 0
final_list = []
for i in range(len(n)) :
    tong  = tong + n[i]
    final_list.append(tong)

print(final_list)
# Out:
# [-1, 0, -1, 0]

# %% [markdown]
# # bai 3

# %%
n = list(map(int, input().split()))
k = int(input())
new = []
for i in range(k):
    n.append(n[i])
for i in range(k, len(n)) :

    new.append(n[i])


   
print(tuple(new))
# Out:
# (3, 4, 5, 1, 2)

# %% [markdown]
# # bai 4

# %%
a = list(input().split())
const = {}
for i in a :
    key , value = i.split(":")
    if key not in const.keys() :
       const[key] = [value]
    else:
        const[key].append(value)
print(const)
# Out:
# {'a': ['1', '3'], 'b': ['2']}

# %% [markdown]
# # bai 5

# %%
n = list(map(int,input().split()))
const = {}
po_num = 0
none_num = 0
nega_num = 0

for i in range(len(n)):
    if n[i] > 0 :
        po_num  += 1
    elif n[i] < 0 :
        nega_num += 1
    else:
        none_num += 1
const['positives'] = po_num
const['zeros'] = none_num
const['negatives'] = nega_num
print(const)
# Out:
# {'positives': 2, 'zeros': 3, 'negatives': 2}

# %% [markdown]
# # bai 6

# %%
n = list(map(int, input().split()))
tong = 0

for i in range(len(n)) :
    tong += n[i]
print(tong)

# %% [markdown]
# # bai 7

# %%
n = tuple(map(int, input().split()))
a= []

for i in range(len(n) - 1, 0 , -1) :
    a.append(n[i])
print(n[0], n[-1] , a)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 5
#       2 a= []
#       4 for i in range(len(n) - 1, 0 ) :
# ----> 5     a.append(n[i])
#       6 print(n[0], n[-1] , a)
#
# IndexError: tuple index out of range

# %% [markdown]
# # bai 8

# %%
n = list(map(str, input().split()))
const = {}
for i in range(len(n)) :
    if n[i] in const :
        const[n[i]] += 1
    else:
        const[n[i]] = 1 
print(const)
# Out:
# {'apple': 2, 'banana': 1}

# %%
dsach = input().split()
kqua = {}
for i in dsach :
    kqua[i] = kqua.get(i, 0 ) + 1
print(kqua)
# Out:
# {'apple': 2, 'banana': 1}

# %% [markdown]
# # bai 9

# %%
dic1 = input().split()
dic2 = input().split()
dict1 = {}
dict2 = {}
for i in dic1 :
    key, value = i.split(":")
    dict1[key] = int(value)
for j in dic2 :
    key1, value1 = j.split(":")
    dict2[key1] = int(value1)
res = dict1.copy()
for i in dict2 :
    if i in dict1 :
        (res[i]) += (dict2[i])
    else:
        res[i] = dict2[i]
print(res)
# Out:
# {'k': 21, 'm': 2, 'n': 3, 'g': 4}

# %% [markdown]
# <!-- # baiu 10\  vViết chương trình nhập vào một danh sách các số nguyên, và số nguyên dương k. In ra
# list gồm các cặp số khác nhau có tổng bằng k. Mỗi cặp là một tuple, hai số trong tuple
# có thể giống nhau, thứ tự xuất hiện trong danh sách của số thứ nhất nhỏ hơn thứ tự của
# số thứ hai. Các tuple trong list được sắp xếp theo thứ tự tăng dần của phần tử đầu tiên
# trong tuple. -->

# %% [markdown]
# Viết chương trình nhập vào một danh sách các số nguyên, và số nguyên dương k. In ra
# list gồm các cặp số khác nhau có tổng bằng k. Mỗi cặp là một tuple, hai số trong tuple
# có thể giống nhau, thứ tự xuất hiện trong danh sách của số thứ nhất nhỏ hơn thứ tự của
# số thứ hai. Các tuple trong list được sắp xếp theo thứ tự tăng dần của phần tử đầu tiên
# trong tuple.

# %%
def finding_sum_of_k (n):
    list_a = []
    for i in range(len(n)) :
        for j in range(i+1 , len(n) ) :
            if n[i] + n[j] == k :
                
                pair = ( n[i] , n[j])
                is_dublicate = False
                for items in list_a :
                    if items[0] == pair[0] and items[1] == pair[1] :
                        is_dublicate = True 
                        break
                if not is_dublicate:
                  
                  list_a.append(pair)
    return list_a

n = list(map(int, input().split()))
k = int(input())
lst_a = finding_sum_of_k(n)
length = len(lst_a)
for i in range(length - 1):
        for j in range(length - i - 1):
            if lst_a[j][0] > lst_a[j+1][0]:
                temp = lst_a[j]
                lst_a[j] = lst_a[j+1]
                lst_a[j+1] = temp
print(lst_a)

# %% [markdown]
# # bai 11

# %% [markdown]
# # bai 12

# %%
n = list(map(int, input().split()))
# max_num = 0 
# for i in range(len(n)) :
#     if n[i] > max_num :
#         max_num = n[i]

new_list =[0]*1000
max_list = 0
min_num = 123212132
for i in range(len(n)):
    new_list[n[i]] += 1
    if new_list[n[i]] > max_list :
        max_list = new_list[n[i]]
        if max_list == new_list[n[i]] :
            if min_num > n[i] :
                min_num = n[i]
print(min_num, max_list)
# Out:
# 1 3

# %%
n = list(map(int, input().split()))

new_list = [0] * 1000 
max_list = 0
min_num = 123212132

for i in range(len(n)):
    new_list[n[i]] += 1
    current_freq = new_list[n[i]]
    
    if current_freq > max_list:
        max_list = current_freq
        min_num = n[i]
    elif current_freq == max_list:
        if n[i] < min_num:
            min_num = n[i]

print(min_num)
# Out:
# 1
